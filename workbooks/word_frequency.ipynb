# %% [markdown]
# # Popular Words

# %% [markdown]
# In this example you will learn how to:
#
# 1. Read the article data
# 2. Given some date range, find articles in that range
# 3. Find the frequent words in the specified articles
# 4. Display results

# %%
# import dependencies 
from os import listdir
from os.path import isfile, join
from datetime import datetime, timedelta
import csv

# %% [markdown]
# ## 1. Read article data from corpus

# %%
# path to corpus directory; change this value as necessary
directory_path = '../corpus'

# read all files
all_files = [f for f in listdir(directory_path) if isfile(join(directory_path, f))]

# create a list to hold data
articles = []

# iterate over each csv file
for f in all_files:

    rows = 0

    # open the file for reading
    with open(join(directory_path, f)) as csvfile:

        # read file contents
        readCSV = csv.reader(csvfile, delimiter=',')

        for row in readCSV:

            # skip header row
            if rows > 0:
                articles.append(row)

            rows += 1

print('Sanity check! Got', len(articles), 'articles.')
# Out:
# Sanity check! Got 67259 articles.

# %% [markdown]
# ## 1.2. Add some helper functions to make life easier later

# %% [markdown]
# The purpose of each of these functions is described in the docstring

# %%
def parse_date(string_date):
    """This function converts string timestamp to a datetime, 
       and zeros out the time (hours, min, etc.)"""
    
    date_format = '%Y-%m-%dT%H:%M:%S.%f%z' if 'T' in string_date else '%Y-%m-%d %H:%M:%S'

    return (datetime.strptime(string_date, date_format)) \
        .replace(hour=0, minute=0, second=0, microsecond=0).date()


def longest_base_word(word_list):
    """Given a list of words, this function finds the longest common sequence from
    the beginning that is common between each words in the list"""

    unique_words = list(set(word_list))

    # if list contains exactly 1 words, return that
    if len(unique_words) == 1:
        return unique_words[0]

    max_len, res = -1, ['']

    # find longest word
    for ele in word_list:
        if len(ele) > max_len:
            max_len = len(ele)

    # loop substrings        
    for idx in range(1, max_len):
        tmp = list(set([t[0:idx] for t in word_list]))
        if len(tmp) > 1:
            break
        res = tmp
    return res[0]


def most_frequent(word_list, n):
    """Given a list of non-unique strings, return top n most frequent strings"""
    
    words = dict.fromkeys(list(set(word_list)), 0)
    
    for k in words.keys():
        words[k] = len([w for w in word_list if w == k])
    
    return [i[1] for i in sorted([(v, k) for k, v in words.items()], reverse=True)][0:n]


def strip_nonalpha(str):
    """Remove non-alphabetic characters, except spaces"""
    
    return ''.join([c for c in list(str.lower()) if 
                    c in [' ', 'ä', 'ö'] or (ord('a') <= ord(c) <= ord('z'))])

# %% [markdown]
# ## 2. Create date range for analysis

# %% [markdown]
# Here we are going to study articles from March 12, 2020 (because it is the last full date of data in the corpus at the time of writing this), and going backwards by 90 days. You may adjust these limits however you want.

# %%
# start from March 12, 2020
base = datetime(2020, 3, 12)

# set how many days backwards from start date you want to analyze
num_days = 90

# make a list of dates n days prior; zeroing out the time part
date_list = [(base - timedelta(days=x))
             .replace(hour=0, minute=0, second=0, microsecond=0).date() 
             for x in range(0, num_days)]

print('Sanity check! Analyzing dates:', date_list[0], 'through', date_list[-1])
# Out:
# Sanity check! Analyzing dates: 2020-03-12 through 2019-12-14

# %% [markdown]
# ## 3. Find words in article titles occurring within the date range

# %%
# Specify minimum word length
# we will ignore all words that are shorter than this length!
# This will eliminate many stop words
min_word_len = 4

# ignore rare words that occurred fewer times than this:
# (adjust this limit as necessary)
min_occurrence = 100

# Make a dictionary to hold temporary results
words = {}

# loop articles where publish date is within date range
for article in [a for a in articles if parse_date(a[0]) in date_list]:

    # sanitize article title, split into words
    title_words = strip_nonalpha(article[1]).split(' ')

    for w in title_words:
        
        # ignore short words
        if len(w) < min_word_len:
            continue
            
        # get base word    
        _key = w[0:min_word_len]
        
        # add word to our dictionary
        if _key in words:
            words[_key].append(w)
        else:
            words[_key] = [w]

# Make a list of most popular words
# key (k) - represents a base word, length of this key is equal to min_word_len
# value (v) - a list of actual words that match that base word, and may contain duplicates
# len(v) - the total number of occurrences that were found within the specified date range
# reverse=True - gives use descending order, i.e. highest frequency items first
top_words = sorted([(len(v), k, v) for k, v in words.items() if len(v) > min_occurrence], reverse=True)

# %% [markdown]
# ## 4. Display results

# %%
for i in range(0, len(top_words)):
    
    # unpack values
    (freq, k, v) = top_words[i]
    
    # longest commmon base word
    base_word = longest_base_word(v)
    # number of diffrent words that share the same base
    unique_word_count = len(list(set(v)))
    # top 5 most frequent words
    full_words = most_frequent(v, 5)
    
    # format output
    display = lambda x,y : str(x).ljust(y, ' ')

    # display row of data
    print(display(str(i + 1) + '.', 5),
          display(base_word, 10),
          display(freq, 5),
          display(unique_word_count, 5),
          ', '.join(full_words))
# Out:
# 1.    suom       1126  181   suomen, suomessa, suomi, suomalainen, suomeen
# 2.    vuot       496   38    vuotta, vuotias, vuotiaan, vuotiaana, vuoteen
# 3.    kuol       483   76    kuollut, kuoli, kuolemasta, kuolleena, kuolemaan
# 4.    koro       477   136   koronaviruksen, koronavirus, koronavirukseen, koronaviruksesta, koronavirusta
# 5.    kuva       474   55    kuvat, kuvan, kuva, kuvasi, kuvassa
# 6.    näin       450   5     näin, näinkin, näinä, näinkö, näinhän
# 7.    palj       410   37    paljastaa, paljasti, paljon, paljastui, paljastavat
# 8.    näyt       374   66    näyttää, näyttelijä, näyttävät, näytti, näyttämään
# 9.    kans       373   62    kanssa, kansanedustaja, kansainvälinen, kansan, kansanedustajat
# 10.   julk       366   64    julkaisi, julki, julkisuuteen, julkaistiin, julkisti
# 11.   kert       360   27    kertoo, kertaa, kertoi, kertovat, kerta
# 12.   poli       346   59    poliisi, poliisin, poliisille, poliisit, poliisilla
# 13.   kaik       342   31    kaikki, kaikkien, kaiken, kaikkea, kaikille
# 14.   video      341   26    video, videon, videolle, videolta, videolla
# 15.   yllä       330   75    yllättäen, yllättävä, yllätti, yllättävän, yllätys
# 16.   kats       325   57    katso, katsomoille, katsoja, katsomossa, katsojat
# 17.   vast       324   88    vastaan, vastaa, vasta, vastaus, vastustajan
# 18.   muut       323   64    muutti, muut, muuttui, muuta, muuttuu
# 19.   pela       306   79    pelaa, pelasti, pelaajat, pelaaja, pelastivat
# 20.   euro       305   41    euroa, euron, euroopan, eurolla, euroja
# 21.   kesk       303   90    kesken, keskellä, keskustan, keskeyttää, keskusta
# 22.   kuin       290   3     kuin, kuinka, kuinen
# 23.   joulu      289   137   joulun, joulu, jouluna, joulua, jouluksi
# 24.   voit       282   67    voitti, voittoon, voit, voiton, voittanut
# 25.   päiv       281   50    päivän, päivää, päivä, päivi, päivässä
# 26.   laps       277   73    lapsen, lapsi, lapset, lapsensa, lapsia
# 27.   päät       265   69    päättyi, päätös, päätyi, päätti, päättyy
# 28.   lähe       257   50    lähes, lähellä, lähetti, lähetys, lähetystä
# 29.   mitä       255   4     mitä, mitään, mitätöidään, mitätöidä
# 30.   uusi       252   25    uusi, uusiksi, uusia, uusin, uusista
# 31.   kiin       250   73    kiinni, kiinassa, kiinan, kiina, kiinaan
# 32.   ruot       249   64    ruotsin, ruotsissa, ruotsi, ruotsalainen, ruotsalaiset
# 33.   tapa       242   67    tapahtui, tapahtuu, tapa, tapaa, tapaus
# 34.   yksi       239   57    yksi, yksin, yksityiskohtia, yksityiskohta, yksinäinen
# 35.   mies       236   14    mies, miestä, miesten, miestään, miesystävänsä
# 36.   oike       233   59    oikeasti, oikein, oikeudessa, oikea, oikeuteen
# 37.   tämä       230   4     tämä, tämän, tämähän, tämäkin
# 38.   ensi       229   44    ensimmäinen, ensi, ensimmäistä, ensimmäisen, ensin
# 39.   nuor       228   54    nuorten, nuori, nuoret, nuorta, nuoria
# 40.   uude       227   31    uuden, uudet, uudesta, uudenvuoden, uudella
# 41.   maailma    226   38    maailman, maailmaa, maailmalla, maailmanmestari, maailmancupissa
# 42.   auto       225   78    auton, auto, autoa, autosta, autolla
# 43.   asia       225   44    asiantuntija, asiaa, asia, asiat, asiasta
# 44.   syyt       224   50    syytä, syyttää, syyte, syytetään, syyttäjä
# 45.   koko       222   50    koko, kokonaan, kokoomuksen, kokoomus, kokoonpano
# 46.   tila       220   53    tilanne, tilanteesta, tilanteen, tilasto, tilanteeseen
# 47.   jatk       220   53    jatkuu, jatkaa, jatkoi, jatkossa, jatkoon
# 48.   seur       219   87    seuraa, seurasi, seuraavaksi, seura, seuraava
# 49.   tässä      216   3     tässä, tässäkö, tässäpä
# 50.   että       216   1     että
# 51.   muist      215   50    muistatko, muistelee, muista, muistuttaa, muistaa
# 52.   vaik       214   56    vaikka, vaikuttaa, vaikutus, vaikea, vaikeaa
# 53.   nais       214   62    naiset, naisten, naisen, naista, naisille
# 54.   tuli       212   45    tuli, tulipalo, tulivat, tulipalossa, tulistui
# 55.   jätt       212   93    jätti, jättää, jättiyllätys, jättimäinen, jättivät
# 56.   puol       211   103   puoli, puolet, puolesta, puolustaa, puoliso
# 57.   vain       207   8     vain, vainio, vainaja, vainonnut, vainoharhaiset
# 58.   ilma       206   79    ilman, ilmaiseksi, ilmassa, ilmatieteen, ilmastonmuutos
# 59.   peru       205   85    peruttu, perui, perussuomalaisten, peruu, peruttiin
# 60.   halu       205   35    haluaa, halusi, halua, haluavat, haluan
# 61.   vuod       204   15    vuoden, vuodessa, vuodeksi, vuodesta, vuodelle
# 62.   ovat       204   2     ovat, ovatko
# 63.   itse       204   46    itse, itsensä, itseään, itselleen, itsestään
# 64.   täll       202   22    tällainen, tällä, tällaista, tällaisia, tällaisen
# 65.   toim       200   80    toimii, toimitusjohtaja, toimi, toimia, toimivat
# 66.   teki       198   16    teki, tekivät, tekijä, tekijää, tekisitkö
# 67.   maal       195   81    maalin, maalia, maali, maalivahti, maaliin
# 68.   saira      193   72    sairaalaan, sairastui, sairaalassa, sairastunut, sairaus
# 69.   nous       188   32    nousi, nousee, nousu, noussut, nousun
# 70.   tule       186   35    tulee, tule, tulevat, tuleen, tulevan
# 71.   suos       186   111   suosikki, suostunut, suosittu, suosio, suositun
# 72.   epäil      186   39    epäillään, epäilty, epäilee, epäiltyä, epäillyn
# 73.   valt       184   67    valtteri, valtava, valtavan, valtion, valtaosa
# 74.   ihmi       184   34    ihmistä, ihmisiä, ihmiset, ihminen, ihmisten
# 75.   hall       184   51    hallitus, hallituksen, hallaaho, hallitukselle, hallituksella
# 76.   viim       182   27    viime, viimeinen, viimein, viimeksi, viimeiseen
# 77.   pääs       181   46    pääsi, pääsee, päässyt, päästä, päässä
# 78.   kaks       181   31    kaksi, kaksoset, kaksosten, kaksikon, kaksikko
# 79.   koti       180   93    kotiin, koti, kotia, kotinsa, kotimainen
# 80.   tunn       174   66    tunnin, tunnettu, tunnistatko, tunnistat, tunnetun
# 81.   jout       174   22    joutui, joutuu, joutunut, joutuneen, joutua
# 82.   koht       172   45    kohti, kohtalo, kohteeksi, kohtasi, kohta
# 83.   kolm       171   41    kolme, kolmen, kolmas, kolmannen, kolmatta
# 84.   yrit       170   42    yritti, yrittää, yritys, yrityksestä, yrityksen
# 85.   valm       170   72    valmentaja, valmis, valmentajan, valmistaa, valmentajalta
# 86.   jälk       170   14    jälkeen, jälkiä, jälkeläistä, jälkeensä, jälkkäri
# 87.   hels       170   28    helsingin, helsingissä, helsinkivantaalla, helsinki, helsinkiläinen
# 88.   milj       169   51    miljoonan, miljoonaa, miljoonia, miljoonien, miljoonalla
# 89.   pala       168   56    palaa, palasi, palata, palamaan, palavasta
# 90.   usko       167   42    uskomaton, uskoo, uskomatonta, uskomattoman, usko
# 91.   löyt       167   31    löytyi, löytyy, löytää, löytynyt, löytö
# 92.   super      166   74    supertähti, super, supertähden, supernanny, supersuosittu
# 93.   käyt       166   60    käyttöön, käytti, käyttää, käytöstä, käyttö
# 94.   hyvä       166   42    hyvä, hyvää, hyvältä, hyväksikäytöstä, hyväksi
# 95.   kosk       163   34    koskaan, koska, koskettava, koskettavan, kosketti
# 96.   tunt       162   58    tuntia, tuntuu, tuntematon, tuntemattoman, tunteita
# 97.   selv       161   50    selvisi, selvitti, selvittää, selvitys, selvinnyt
# 98.   mari       161   28    marinin, marin, mari, maria, marinia
# 99.   eläm       160   44    elämä, elämän, elämää, elämänsä, elämäni
# 100.  vanh       159   51    vanha, vanhemmat, vanhat, vanhan, vanhin
# 101.  poik       158   51    poika, poikkeuksellinen, poikkeuksellisen, poikansa, poikki
# 102.  yhte       157   56    yhteen, yhteiskuvassa, yhteiskuvan, yhteys, yhteydessä
# 103.  taka       156   47    takaisin, takana, takaa, takaisku, takavuosien
# 104.  tuom       155   53    tuomittiin, tuomion, tuomittu, tuomio, tuomitsi
# 105.  matk       155   80    matkustaa, matkalla, matka, matkusti, matkustaja
# 106.  joka       155   11    joka, jokainen, jokaisen, jokaisella, jokaista
# 107.  harr       155   29    harry, harryn, harrya, harrylle, harri
# 108.  tapp       154   60    tappio, tappaa, tappoi, tapparan, tappara
# 109.  aika       154   29    aika, aikaa, aikana, aikaan, aikaisin
# 110.  liik       153   77    liikaa, liikuttui, liikkeellä, liikkeelle, liikkuu
# 111.  prin       152   10    prinssi, prinsessa, prinssin, princess, prinze
# 112.  olla       150   5     olla, ollaan, ollakseen, ollakaan, ollaanhan
# 113.  perh       148   57    perheen, perhe, perheenäiti, perheensä, perheenisä
# 114.  paik       148   44    paikalle, paikka, paikalla, paikassa, paikkaa
# 115.  väli       147   63    väliin, välittömästi, välillä, välit, välistä
# 116.  tois       147   34    toisen, toista, toiseen, toisiaan, toiselle
# 117.  suur       147   56    suuri, suurin, suurempi, suuren, suurimman
# 118.  minu       145   21    minua, minulle, minuutissa, minulla, minun
# 119.  täys       143   22    täysin, täysi, täysosumia, täysillä, täysosumaa
# 120.  suor       143   33    suoraan, suora, suoritus, suorat, suoraa
# 121.  lent       143   68    lentokentällä, lentää, lento, lentokoneessa, lentokoneen
# 122.  pois       142   26    pois, poissa, poistui, poisti, poistua
# 123.  mutt       142   2     mutta, muttei
# 124.  kaup       142   65    kaupungin, kaupunki, kaupan, kaupassa, kauppakeskuksessa
# 125.  upea       141   11    upea, upean, upeat, upeasti, upeaa
# 126.  venä       139   46    venäjän, venäjällä, venäjä, venäläinen, venäläiset
# 127.  niin       139   5     niin, niinistö, niinistön, niina, niinan
# 128.  myös       139   3     myös, myöskään, myöskin
# 129.  tiet       138   44    tietoa, tietää, tieto, tietoja, tietä
# 130.  some       138   44    somessa, somen, some, sometili, someseuraajat
# 131.  tänä       137   3     tänään, tänä, tänäkin
# 132.  hurj       137   16    hurja, hurjan, hurjat, hurjasti, hurjasta
# 133.  pitä       136   14    pitää, pitäisi, pitänyt, pitävät, pitäisikö
# 134.  läht       135   33    lähti, lähtee, lähteä, lähtenyt, lähtivät
# 135.  saat       134   32    saattaa, saat, saattoi, saatu, saatiin
# 136.  peli       134   62    pelikielto, peli, pelin, pelissä, peliä
# 137.  kova       134   20    kova, kovaa, kovan, kovat, kovassa
# 138.  erik       134   34    erikoinen, erika, erikoisen, erik, erikoista
# 139.  vielä      133   5     vielä, vieläkin, vieläkö, vieläkään, vieläpä
# 140.  mene       133   48    menetti, menee, menehtyi, menettää, menevät
# 141.  tied       132   28    tiedätkö, tiedetään, tiedä, tiedot, tiedossa
# 142.  ollut      132   3     ollut, ollutta, ollutkaan
# 143.  huip       132   81    huippumalli, huippulupaus, huipulle, huippuvalmentaja, huippuurheilija
# 144.  vara       131   66    varasti, varalta, varautuu, varautua, varassa
# 145.  tode       130   20    todella, todellinen, todellisen, todellista, todennäköisesti
# 146.  palk       130   76    palkka, palkittiin, palkkaa, palkat, palkintopallille
# 147.  vali       129   64    valioliigan, valittu, valinta, valitsi, valita
# 148.  tältä      129   1     tältä
# 149.  raju       129   21    raju, rajusti, rajut, rajun, rajuja
# 150.  pari       127   48    pari, pariskunnan, pariskunta, parikka, parin
# 151.  kunn       127   51    kunnossa, kunnolla, kunnes, kunnianosoitus, kunnon
# 152.  vuos       126   30    vuosi, vuosia, vuosien, vuosikymmenen, vuosittain
# 153.  mieh       126   20    miehen, miehet, miehiä, miehensä, miehelle
# 154.  käsi       126   54    käsistä, käsittämätön, käsi, käsiin, käsittämätöntä
# 155.  kuul       126   61    kuuluu, kuullut, kuulla, kuuli, kuuluisa
# 156.  ravi       125   35    ravivihje, ravintolassa, ravintolan, ravintola, ravintolat
# 157.  puhe       124   64    puhelin, puhetta, puhelimen, puhe, puheista
# 158.  meghan     124   11    meghan, meghanin, meghanille, meghania, meghanista
# 159.  jopa       124   1     jopa
# 160.  kasv       123   56    kasvaa, kasvot, kasvanut, kasvoi, kasvonsa
# 161.  jouk       123   57    joukkue, joukossa, joukkueen, joukkuekaveri, jouko
# 162.  seks       122   59    seksuaalisesta, seksuaalirikoksista, seksiä, seksiin, seksikäs
# 163.  mite       122   3     miten, mitenkään, mitellään
# 164.  lopp       122   43    lopputulos, loppu, loppua, loppuu, loppui
# 165.  hiih       122   64    hiihdon, hiihtotähti, hiihtäjä, hiihto, hiihtää
# 166.  kann       120   38    kannattaa, kannata, kannatus, kannanotto, kannustaa
# 167.  brit       120   53    britannian, britanniassa, britney, britannia, brittinainen
# 168.  nämä       119   1     nämä
# 169.  miel       119   59    mieltä, mieleen, mieluummin, mieletön, mielipiteitä
# 170.  enne       118   10    ennen, ennennäkemättömän, ennenkin, ennennäkemätön, ennennäkemätöntä
# 171.  muka       116   14    mukaan, mukana, mukanaan, mukaansa, mukavia
# 172.  maks       116   41    maksaa, maksamaan, maksoi, maksetaan, maksutonta
# 173.  järk       116   25    järkyttyi, järkyttävä, järkyttävän, järkytti, järkeä
# 174.  ihme       116   40    ihmettä, ihme, ihmettelee, ihmetyttää, ihmeissään
# 175.  sala       115   71    salaa, salaisuus, salaisuuden, salainen, salaperäisen
# 176.  para       115   38    paras, parasta, parantaa, paransi, paratiisista
# 177.  tava       114   30    tavalla, tavaraa, tavallista, tavan, tavallinen
# 178.  tutk       113   42    tutkii, tutkimus, tutkijat, tutkitaan, tutkija
# 179.  harv       113   23    harvinainen, harvinaisen, harvinaisessa, harvey, harvoin
# 180.  vaat       111   47    vaatii, vaati, vaativat, vaatteista, vaatinut
# 181.  huom       111   34    huomion, huomasitko, huomasi, huomio, huomenna
# 182.  pitk       110   23    pitkään, pitkä, pitkän, pitkälle, pitkästä
# 183.  kohu       109   65    kohuvalmentaja, kohu, kohun, kohupelaaja, kohuttu
# 184.  hetk       109   16    hetki, hetken, hetkellä, hetkessä, hetket
# 185.  ampu       109   57    ampui, ampumahiihdon, ampumahiihdossa, amputoitiin, ampumista
# 186.  viik       108   29    viikolla, viikon, viikonloppuna, viikko, viikossa
# 187.  äiti       107   21    äiti, äitinsä, äitiä, äitiydestä, äitinä
# 188.  sitten     107   3     sitten, sittenkin, sittenkään
# 189.  teke       106   19    tekee, tekevät, tekemään, tekevän, tekeytyi
# 190.  norja      106   36    norjan, norjassa, norjalaistähti, norjalainen, norjalaiset
# 191.  hert       106   13    herttuatar, herttuaparin, herttaisen, herttuaparia, herttuapari
# 192.  esit       106   38    esitteli, esittelee, esitti, esittää, esitys
# 193.  nainen     105   2     nainen, nainenkin
# 194.  mark       105   33    markkanen, markus, markku, markkasen, marko
# 195.  kall       105   26    kalle, kalliiksi, kallio, kallis, kallista
# 196.  kais       105   5     kaisa, kaistalle, kaistan, kaistaa, kaisan
# 197.  pain       104   58    paino, painajainen, painoi, painoa, paineet
# 198.  kunin      104   26    kuningatar, kuningattaren, kuninkaalliset, kuningas, kuningattarelle
# 199.  vill       103   32    ville, villa, villitsi, villiintyi, villen
# 200.  tytt       103   34    tyttärensä, tyttö, tyttären, tyttöä, tyttärelleen
# 201.  trump      102   7     trump, trumpin, trumpia, trumpkin, trumpilta
# 202.  ihan       102   16    ihan, ihana, ihanan, ihanimmat, ihanat
# 203.  huol       102   45    huolimatta, huolta, huolestui, huolissaan, huolettaa
# 204.  yhdysval   101   24    yhdysvalloissa, yhdysvaltain, yhdysvallat, yhdysvaltoihin, yhdysvaltojen
# 205.  täht       101   40    tähti, tähtihyökkääjä, tähtien, tähtipelaaja, tähtipelaajan
# 206.  tall       101   34    tallentui, tallinnan, tallentuivat, tallensi, tallinnassa
# 207.  raha       101   34    rahaa, rahat, rahasta, rahan, rahalla
# 208.  help       101   31    helppo, helposti, helppoa, helpottaa, helpotti

# %% [markdown]
# ## Top 20 Topics

# %%
n = 1

print('IL Suosituimmat jutun aiheet', date_list[-1], '-', date_list[0], '\n')

for entry in top_words[0: 20]:
    print(str(n).ljust(3,' '), ',\n'.join(most_frequent(entry[-1], 1)))
    n += 1
# Out:
# IL Suosituimmat jutun aiheet 2019-12-14 - 2020-03-12
#
# 1   suomen
# 2   vuotta
# 3   kuollut
# 4   koronaviruksen
# 5   kuvat
# 6   näin
# 7   paljastaa
# 8   näyttää
# 9   kanssa
# 10  julkaisi
# 11  kertoo
# 12  poliisi
# 13  kaikki
# 14  video
# 15  yllättäen
# 16  katso
# 17  vastaan
# 18  muutti
# 19  pelaa
# 20  euroa

# %% [markdown]
# # [&laquo; Previous Lab](getting_started.ipynb)             [Next Lab &raquo;](plotting_frequencies.ipynb)
